# %%
# importing for ipywidgets
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
#import to filter warnings
import warnings
warnings.filterwarnings('ignore')
#!pip install numpy
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from matplotlib.pyplot import xticks
# %matplotlib inline
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(12,8)})
pd.set_option('display.max_rows', 400)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', -1)
import calendar
import datetime as dt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

from nltk.tokenize import RegexpTokenizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# !pip install -U textblob

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

# %% [raw]
# nltk.download('movie_reviews')
# nltk.download('punkt')
# nltk.download()

# %%
Maithili_Thakur=pd.read_csv("scrapeng.csv")
words = Maithili_Thakur.comments.str.lower().str.cat(sep=' ').split()
Maithili_Thakur_comments=" ".join(words)

# %%
Teri_Mittidf=pd.read_csv("This version of 'Teri Mitti' will leave you amazed.csv")
words = Teri_Mittidf.comments.str.lower().str.cat(sep=' ').split()
Teri_Mitti_comments=".".join(words)

# %%
Tirupati_Temple=pd.read_csv("Wignew.csv",encoding='utf-8-sig')
words = Tirupati_Temple.comments.str.lower().str.cat(sep=' ').split()
Tirupati_comments=".".join(words)

# %%
Mob_lynching=pd.read_excel("sadhus.xlsx")
words = Mob_lynching.comments.str.lower().str.cat(sep=' ').split()
Mob_lynching_comments=".".join(words)

# %%
Police_overturns=pd.read_csv("Police_Overturns_veg_cart.csv")
words = Police_overturns.comments.str.lower().str.cat(sep=' ').split()
Police_Overturns_comments=".".join(words)

# %%
tokenizer = RegexpTokenizer(r'\w+')
result = tokenizer.tokenize(Maithili_Thakur_comments)
text = " ".join(result)
tokens_stopwords = word_tokenize(text)

no_stopwords_tokens = [word for word in tokens_stopwords if not word in stopwords.words()]

#print(no_stopwords_tokens)
#print(text_tokens)

# %%
textblock=" ".join(tokens_stopwords)

textblock1=" ".join(no_stopwords_tokens)

# %%
from collections import Counter
top_N = 1000
word_all = pd.DataFrame(Counter(no_stopwords_tokens).most_common(top_N),
                    columns=['word', 'Freq']).set_index('word')
word_count=word_all[word_all.Freq>1]
word_count
# Out:
#                  Freq
# word
# song             57
# voice            45
# english          28
# beautiful        24
# songs            22
# singer           21
# sung             18
# god              18
# maithili         14
# time             14
# melodious        13
# keep             13
# sweet            12
# bless            12
# beautifully      11
# singing          11
# 1                11
# amazing          11
# perfect          10
# good             10
# wow              10
# music            9
# sing             9
# love             9
# first            9
# like             8
# versatile        8
# version          7
# lovely           7
# 2                7
# wonderful        6
# much             6
# heard            6
# see              6
# r                6
# best             5
# dear             5
# sang             5
# thakur           4
# never            4
# even             4
# hindi            4
# really           4
# girl             4
# ever             4
# ...

# %%
@interact
def wordcloud(video=[Maithili_Thakur_comments,Teri_Mitti_comments,Tirupati_comments,Mob_lynching_comments, Police_Overturns_comments]):
    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(video)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    return wordcloud
# Out:
# interactive(children=(Dropdown(description='video', options=('maithili.thakur.sings.her.version.of."perfect"..…

# %% [raw]
# sent          = TextBlob(textblock)
# polarity      = sent.sentiment.polarity
# subjectivity  = sent.sentiment.subjectivity
#
# sent          = TextBlob(text, analyzer = NaiveBayesAnalyzer())
# classification= sent.sentiment.classification
# positive      = sent.sentiment.p_pos
# negative      = sent.sentiment.p_neg
# print("Polarity:",round(polarity,1),"\n","Subjectivity:",round(subjectivity,1),"\n","Sentiment: ",classification,"\n","Positive Value: ",round(positive,1),"\n","Negative Value: ",round(negative,1))

# %%
@interact
def sentiment(video=[Maithili_Thakur_comments,Teri_Mitti_comments,Tirupati_comments,Mob_lynching_comments,Police_Overturns_comments]):
    tokenizer = RegexpTokenizer(r'\w+')
    result = tokenizer.tokenize(video)
    text = " ".join(result)
    tokens_stopwords = word_tokenize(text)
    textblock=" ".join(tokens_stopwords)
    sent          = TextBlob(textblock)
    polarity      = sent.sentiment.polarity
    subjectivity  = sent.sentiment.subjectivity
    sent          = TextBlob(text, analyzer = NaiveBayesAnalyzer())
    classification= sent.sentiment.classification
    positive      = sent.sentiment.p_pos
    negative      = sent.sentiment.p_neg
    if (polarity <0.2 and polarity >= 0):
        Senti="Neutral"
    elif (polarity > 0.2):
        Senti="Positive"
    else:
        Senti="Negative"
        
    return print("Polarity:",round(polarity,2),"\n","Subjectivity:",round(subjectivity,1),"\n","Sentiment: ",Senti)
# Out:
# interactive(children=(Dropdown(description='video', options=('maithili.thakur.sings.her.version.of."perfect"..…

# %% [markdown]
# #### Output is categorized between two — Polarity and Subjectivity.
#
# ##### Polarity is a float value within the range [-1.0 to 1.0] where :

# %% [raw]
#     0 indicates neutral,
#    +1 indicates a very positive sentiment
#    -1 represents a very negative sentiment.
#
# Subjectivity is a float value within the range [0.0 to 1.0] where 0.0 is very objective and 1.0 is very subjective.
#
# Subjective sentence expresses some personal feelings, views, beliefs, opinions, allegations, desires, beliefs, suspicions, and speculations where as Objective sentences are factual.
